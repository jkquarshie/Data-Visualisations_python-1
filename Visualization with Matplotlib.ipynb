# %%
# %matplotlib --list  ##check the backends available
# Out:
# Available matplotlib backends: ['tk', 'gtk', 'gtk3', 'wx', 'qt4', 'qt5', 'qt', 'osx', 'nbagg', 'notebook', 'agg', 'svg', 'pdf', 'ps', 'inline', 'ipympl', 'widget']

# %%
import matplotlib

# %%
matplotlib.is_interactive() ##check if the matplotlib backend is interactive or not)
# Out:
# False

# %%
matplotlib.interactive(True) #set matplotlib interactive mode to True

# %%
matplotlib.get_backend()
# Out:
# 'module://ipykernel.pylab.backend_inline'

# %%
matplotlib.use('nbagg') #set backend to 'nbagg'

# %%
matplotlib.get_backend()
# Out:
# 'nbAgg'

# %%
import matplotlib.pyplot as plt #now import matplotlib as plt

plt.ion() #set the interactive mode or toggle it on
matplotlib.is_interactive() #check if interactive mode is now on; and yes, it is.
# Out:
# True

# %%
plt.plot([2, 4, 6, 8], [4, 8, 12, 16]) #lets plot a simple chart to see the outcome
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# Now we can see our plot has several features, and buttons which we can use to zoom, shift or even save the plot

# %%
plt.title('Interactive Plot') #because we are in interactive mode, all new changes 

#are effected in real time, unless you put it off
# Out:
# Text(0.5, 1.0, 'Interactive Plot')

# %%
import numpy as np

plt.ion()
matplotlib.is_interactive()
# Out:
# True

# %%
plt.plot([2,4,6,8], [4,6,8,10], color = 'red')
